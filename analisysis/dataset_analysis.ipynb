# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from collections import Counter
from utils import helper

# %% [markdown]
# # Analisi inziale csv

# %% [markdown]
# ricerca e rimozione di file audio duplicati. Lettura file csv originale.

# %%
audio_df = pd.read_csv('C:/underwater-classification/datasets_csv/audio_features_dataset.csv')

# %% [markdown]
# stampa file audio

# %%
audio_df
# Out:
#                                        Nome file      Classe    Sottoclasse  \
# 0           0f9867d8-fcf7-40d1-b846-3f7fb8100eb7  Non-Target  Ambient Noise
# 1           2b68b3a9-7c0d-4452-bbe5-cc99b5d4fb61  Non-Target  Ambient Noise
# 2           2f574049-3325-446c-a8ac-2e5b31e9e32f  Non-Target  Ambient Noise
# 3           30679527-fd7a-4cad-8c7d-cb1bcc07604d  Non-Target  Ambient Noise
# 4           f9652ad2-39f5-41b4-a8e4-89171a864f03  Non-Target  Ambient Noise
# ...                                          ...         ...            ...
# 2658    SanctSound_OC01_03_ship_20191106T223751Z      Target         Vessel
# 2659    SanctSound_OC02_01_ship_20190419T233040Z      Target         Vessel
# 2660    SanctSound_OC03_02_ship_20200228T080107Z      Target         Vessel
# 2661  SanctSound_SB03_09_vessel_20200415T161235Z      Target         Vessel
# 2662                                  ship_small      Target         Vessel
#
#       Ampiezza del segnale     Durata  Frequenza  Numero di canali      Fase  \
# 0                 0.226026  31.207619      44100                 1 -0.068573
# 1                 0.646487  31.207619      44100                 1  0.003324
# 2                 0.391676  31.207619      44100                 1 -0.031078
# 3                 0.200377  31.207619      44100                 1  0.013213
# 4                 0.753663  31.207619      44100                 1  0.050887
# ...                    ...        ...        ...               ...       ...
# 2658              0.251221   5.305042      48000                 1  0.000000
# 2659              0.326813  60.000000      48000                 1  0.000000
# 2660              0.251221  60.000000      48000                 1 -0.000031
# 2661              0.251129   5.000021      48000                 1  0.000000
# 2662              0.690488  51.876000      32000                 2  0.000000
#
#       Frequenza massima interna          Bit Depth Forma d'onda
# 0                           0.0     MPEG Layer III   (1376256,)
# 1                           0.0     MPEG Layer III   (1376256,)
# 2                           0.0     MPEG Layer III   (1376256,)
# 3                           0.0     MPEG Layer III   (1376256,)
# 4                           0.0     MPEG Layer III   (1376256,)
# ...                         ...                ...          ...
# 2658                        0.0  Signed 16 bit PCM    (254642,)
# 2659                        0.0  Signed 16 bit PCM   (2880000,)
# 2660                        0.0  Signed 16 bit PCM   (2880000,)
# 2661                        0.0  Signed 16 bit PCM    (240001,)
# 2662                        0.0     MPEG Layer III   (1660032,)
#
# [2663 rows x 11 columns]

# %% [markdown]
# ricerca duplicati

# %%
duplicates = audio_df[audio_df.duplicated(subset=['Nome file'],keep=False)]
duplicates
# Out:
#      Nome file      Classe                         Sottoclasse  \
# 103   72021005  Non-Target                        Bearded Seal
# 104   7202100T  Non-Target                        Bearded Seal
# 105   7202100V  Non-Target                        Bearded Seal
# 106   7202100Z  Non-Target                        Bearded Seal
# 108   78018002  Non-Target                        Bearded Seal
# 109   78018003  Non-Target                        Bearded Seal
# 111   7801800B  Non-Target                        Bearded Seal
# 112   7801800D  Non-Target                        Bearded Seal
# 113   7801800H  Non-Target                        Bearded Seal
# 114   7801800J  Non-Target                        Bearded Seal
# 209   72021005  Non-Target                       Bowhead Whale
# 211   7202100T  Non-Target                       Bowhead Whale
# 212   7202100V  Non-Target                       Bowhead Whale
# 213   7202100Z  Non-Target                       Bowhead Whale
# 214   78018002  Non-Target                       Bowhead Whale
# 215   78018003  Non-Target                       Bowhead Whale
# 216   7801800B  Non-Target                       Bowhead Whale
# 217   7801800D  Non-Target                       Bowhead Whale
# 218   7801800H  Non-Target                       Bowhead Whale
# 219   7801800J  Non-Target                       Bowhead Whale
# 954   7702800U  Non-Target             Long-Finned Pilot Whale
# 955   7702800V  Non-Target             Long-Finned Pilot Whale
# 956   7702800X  Non-Target             Long-Finned Pilot Whale
# 962   7702801F  Non-Target             Long-Finned Pilot Whale
# 965   7702801M  Non-Target             Long-Finned Pilot Whale
# 998   91012009  Non-Target                  Melon Headed Whale
# 999   9101200B  Non-Target                  Melon Headed Whale
# 1002  9101200K  Non-Target                  Melon Headed Whale
# 1007  9101201E  Non-Target                  Melon Headed Whale
# 1013  91012022  Non-Target                  Melon Headed Whale
# 1042  91012048  Non-Target                  Melon Headed Whale
# 1043  91012049  Non-Target                  Melon Headed Whale
# 1230  84021003  Non-Target         Pantropical Spotted Dolphin
# 1461  84016002  Non-Target  Short-Finned (Pacific) Pilot Whale
# 1462  8401600B  Non-Target  Short-Finned (Pacific) Pilot Whale
# 1561  7702800U  Non-Target                         Sperm Whale
# 1562  7702800V  Non-Target                         Sperm Whale
# 1563  7702800X  Non-Target                         Sperm Whale
# 1564  7702801F  Non-Target                         Sperm Whale
# 1565  7702801M  Non-Target                         Sperm Whale
# 1573  84016002  Non-Target                         Sperm Whale
# 1574  8401600B  Non-Target                         Sperm Whale
# 1577  84021003  Non-Target                         Sperm Whale
# 1601  91012009  Non-Target                         Sperm Whale
# 1602  9101200B  Non-Target                         Sperm Whale
# 1603  9101200K  Non-Target                         Sperm Whale
# 1604  9101201E  Non-Target                         Sperm Whale
# 1605  91012022  Non-Target                         Sperm Whale
# 1606  91012048  Non-Target                         Sperm Whale
# 1607  91012049  Non-Target                         Sperm Whale
#
#       Ampiezza del segnale       Durata  Frequenza  Numero di canali  \
# 103               0.550293   142.500000      10240                 1
# 104               0.449707     2.835938      10240                 1
# 105               0.341309     2.835938      10240                 1
# 106               0.509766     2.465625      10240                 1
# 108               0.749512    45.300000      10240                 1
# 109               0.547363    11.343750      10240                 1
# 111               0.557129     2.751562      10240                 1
# 112               0.618164     2.751562      10240                 1
# 113               0.665527     3.618750      10240                 1
# 114               0.600098     3.618750      10240                 1
# 209               0.550293   142.500000      10240                 1
# 211               0.449707     2.835938      10240                 1
# 212               0.341309     2.835938      10240                 1
# 213               0.509766     2.465625      10240                 1
# 214               0.749512    45.300000      10240                 1
# 215               0.547363    11.343750      10240                 1
# 216               0.557129     2.751562      10240                 1
# 217               0.618164     2.751562      10240                 1
# 218               0.665527     3.618750      10240                 1
# 219               0.600098     3.618750      10240                 1
# 954               0.634277     0.939844      81920                 1
# 955               0.725586     1.040625      81920                 1
# 956               0.654297     1.328906      81920                 1
# 962               0.584961     1.296094      81920                 1
# 965               0.363770     0.099988      81920                 1
# 998               0.544922     0.945300      81920                 1
# 999               0.613281     1.130969      81920                 1
# 1002              0.377930     1.048181      81920                 1
# 1007              0.299316     0.603113      81920                 1
# 1013              0.856934     0.853113      81920                 1
# 1042              0.351074     0.163916      81920                 1
# 1043              0.703613     0.163916      81920                 1
# 1230              0.611816     2.835938      40960                 1
# 1461              0.947266    43.962325      40000                 1
# 1462              0.996521  1260.000000      44100                 1
# 1561              0.634277     0.939844      81920                 1
# 1562              0.725586     1.040625      81920                 1
# 1563              0.654297     1.328906      81920                 1
# 1564              0.584961     1.296094      81920                 1
# 1565              0.363770     0.099988      81920                 1
# 1573              0.947266    43.962325      40000                 1
# 1574              0.996521  1260.000000      44100                 1
# 1577              0.611816     2.835938      40960                 1
# 1601              0.544922     0.945300      81920                 1
# 1602              0.613281     1.130969      81920                 1
# 1603              0.377930     1.048181      81920                 1
# 1604              0.299316     0.603113      81920                 1
# 1605              0.856934     0.853113      81920                 1
# 1606              0.351074     0.163916      81920                 1
# 1607              0.703613     0.163916      81920                 1
#
#           Fase  Frequenza massima interna          Bit Depth Forma d'onda
# 103   0.000977                        0.0  Signed 16 bit PCM   (1459200,)
# 104  -0.010254                        0.0  Signed 16 bit PCM     (29040,)
# 105  -0.021973                        0.0  Signed 16 bit PCM     (29040,)
# 106  -0.019043                        0.0  Signed 16 bit PCM     (25248,)
# 108  -0.169434                        0.0  Signed 16 bit PCM    (463872,)
# 109  -0.102539                        0.0  Signed 16 bit PCM    (116160,)
# 111  -0.203613                        0.0  Signed 16 bit PCM     (28176,)
# 112  -0.048828                        0.0  Signed 16 bit PCM     (28176,)
# 113  -0.229980                        0.0  Signed 16 bit PCM     (37056,)
# 114   0.175781                        0.0  Signed 16 bit PCM     (37056,)
# 209   0.000977                        0.0  Signed 16 bit PCM   (1459200,)
# 211  -0.010254                        0.0  Signed 16 bit PCM     (29040,)
# 212  -0.021973                        0.0  Signed 16 bit PCM     (29040,)
# 213  -0.019043                        0.0  Signed 16 bit PCM     (25248,)
# 214  -0.169434                        0.0  Signed 16 bit PCM    (463872,)
# 215  -0.102539                        0.0  Signed 16 bit PCM    (116160,)
# 216  -0.203613                        0.0  Signed 16 bit PCM     (28176,)
# 217  -0.048828                        0.0  Signed 16 bit PCM     (28176,)
# 218  -0.229980                        0.0  Signed 16 bit PCM     (37056,)
# 219   0.175781                        0.0  Signed 16 bit PCM     (37056,)
# 954   0.052246                        0.0  Signed 16 bit PCM     (76992,)
# 955   0.007324                        0.0  Signed 16 bit PCM     (85248,)
# 956  -0.008301                        0.0  Signed 16 bit PCM    (108864,)
# 962  -0.053711                        0.0  Signed 16 bit PCM    (106176,)
# 965  -0.039551                        0.0  Signed 16 bit PCM      (8191,)
# 998   0.033203                        0.0  Signed 16 bit PCM     (77439,)
# 999  -0.014648                        0.0  Signed 16 bit PCM     (92649,)
# 1002  0.066406                        0.0  Signed 16 bit PCM     (85867,)
# 1007 -0.012207                        0.0  Signed 16 bit PCM     (49407,)
# 1013 -0.016113                        0.0  Signed 16 bit PCM     (69887,)
# 1042  0.138184                        0.0  Signed 16 bit PCM     (13428,)
# 1043 -0.020020                        0.0  Signed 16 bit PCM     (13428,)
# 1230  0.045410                        0.0  Signed 16 bit PCM    (116160,)
# 1461 -0.050781                        0.0  Signed 16 bit PCM   (1758493,)
# 1462  0.005249                        0.0  Signed 16 bit PCM  (55566000,)
# 1561  0.052246                        0.0  Signed 16 bit PCM     (76992,)
# 1562  0.007324                        0.0  Signed 16 bit PCM     (85248,)
# 1563 -0.008301                        0.0  Signed 16 bit PCM    (108864,)
# 1564 -0.053711                        0.0  Signed 16 bit PCM    (106176,)
# 1565 -0.039551                        0.0  Signed 16 bit PCM      (8191,)
# 1573 -0.050781                        0.0  Signed 16 bit PCM   (1758493,)
# 1574  0.005249                        0.0  Signed 16 bit PCM  (55566000,)
# 1577  0.045410                        0.0  Signed 16 bit PCM    (116160,)
# 1601  0.033203                        0.0  Signed 16 bit PCM     (77439,)
# 1602 -0.014648                        0.0  Signed 16 bit PCM     (92649,)
# 1603  0.066406                        0.0  Signed 16 bit PCM     (85867,)
# 1604 -0.012207                        0.0  Signed 16 bit PCM     (49407,)
# 1605 -0.016113                        0.0  Signed 16 bit PCM     (69887,)
# 1606  0.138184                        0.0  Signed 16 bit PCM     (13428,)
# 1607 -0.020020                        0.0  Signed 16 bit PCM     (13428,)

# %% [markdown]
# risultano 50 file audio duplicati. Procedere con la rimozione

# %%
audio_df.drop_duplicates(subset=['Nome file'], keep=False, inplace=True)

# %%
audio_df.to_csv("audio_features_dataset_no_duplicates.csv")

# %% [markdown]
# stampa dataframe finale senza duplicati.

# %%
audio_df
# Out:
#                                        Nome file      Classe    Sottoclasse  \
# 0           0f9867d8-fcf7-40d1-b846-3f7fb8100eb7  Non-Target  Ambient Noise
# 1           2b68b3a9-7c0d-4452-bbe5-cc99b5d4fb61  Non-Target  Ambient Noise
# 2           2f574049-3325-446c-a8ac-2e5b31e9e32f  Non-Target  Ambient Noise
# 3           30679527-fd7a-4cad-8c7d-cb1bcc07604d  Non-Target  Ambient Noise
# 4           f9652ad2-39f5-41b4-a8e4-89171a864f03  Non-Target  Ambient Noise
# ...                                          ...         ...            ...
# 2658    SanctSound_OC01_03_ship_20191106T223751Z      Target         Vessel
# 2659    SanctSound_OC02_01_ship_20190419T233040Z      Target         Vessel
# 2660    SanctSound_OC03_02_ship_20200228T080107Z      Target         Vessel
# 2661  SanctSound_SB03_09_vessel_20200415T161235Z      Target         Vessel
# 2662                                  ship_small      Target         Vessel
#
#       Ampiezza del segnale     Durata  Frequenza  Numero di canali      Fase  \
# 0                 0.226026  31.207619      44100                 1 -0.068573
# 1                 0.646487  31.207619      44100                 1  0.003324
# 2                 0.391676  31.207619      44100                 1 -0.031078
# 3                 0.200377  31.207619      44100                 1  0.013213
# 4                 0.753663  31.207619      44100                 1  0.050887
# ...                    ...        ...        ...               ...       ...
# 2658              0.251221   5.305042      48000                 1  0.000000
# 2659              0.326813  60.000000      48000                 1  0.000000
# 2660              0.251221  60.000000      48000                 1 -0.000031
# 2661              0.251129   5.000021      48000                 1  0.000000
# 2662              0.690488  51.876000      32000                 2  0.000000
#
#       Frequenza massima interna          Bit Depth Forma d'onda
# 0                           0.0     MPEG Layer III   (1376256,)
# 1                           0.0     MPEG Layer III   (1376256,)
# 2                           0.0     MPEG Layer III   (1376256,)
# 3                           0.0     MPEG Layer III   (1376256,)
# 4                           0.0     MPEG Layer III   (1376256,)
# ...                         ...                ...          ...
# 2658                        0.0  Signed 16 bit PCM    (254642,)
# 2659                        0.0  Signed 16 bit PCM   (2880000,)
# 2660                        0.0  Signed 16 bit PCM   (2880000,)
# 2661                        0.0  Signed 16 bit PCM    (240001,)
# 2662                        0.0     MPEG Layer III   (1660032,)
#
# [2613 rows x 11 columns]

# %% [markdown]
# # Analisi dataset

# %% [markdown]
# lettura file csv e conversione in un dataframe pandas

# %%
df = pd.read_csv("C:/underwater-classification/datasets_csv/audio_features_dataset_no_duplicates.csv")

# %% [markdown]
# estrarre informazioni dal dataframe

# %%
amplitudes = df['Ampiezza del segnale'].tolist()
durations = df['Durata'].tolist()
frequencies = df['Frequenza'].tolist()
num_channels_list = df['Numero di canali'].tolist()
phases = df['Fase'].tolist()
max_internal_frequencies = df['Frequenza massima interna'].tolist()
bit_depths = df['Bit Depth'].tolist()

# %% [markdown]
# funzione per creazione grafiici generici

# %%
def plot_distribution(values, title, x_label):
    counter = Counter(values)
    unique_values = sorted(counter.keys())
    counts = [counter[value] for value in unique_values]

    plt.figure(figsize=(12, 8))
    bar_width = 0.8  
    indices = range(len(unique_values))

    bars = plt.bar(indices, counts, color='skyblue', edgecolor='black', width=bar_width)

    for bar, count in zip(bars, counts):
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, height, str(count), ha='center', va='bottom', fontsize=10)

    plt.title(title, fontsize=16)
    plt.xlabel(x_label, fontsize=14)
    plt.ylabel('Occorrenze', fontsize=14)
    plt.xticks(indices, unique_values, rotation=90, ha='right')
    plt.xticks(rotation=90)
    plt.grid(True, axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Distribuzione ampiezze del segnale

# %%
def plot_distribution_boxplot(values, title):
    plt.figure(figsize=(10, 6))
    plt.plot(values)
    plt.title(title)
    plt.xlabel('Indice')
    plt.ylabel('Valore')
    plt.grid(True)
    plt.show()

# %%
plot_distribution_boxplot(amplitudes, 'Distribuzione dei Valori di Ampiezza del Segnale')

# %% [markdown]
# # Distribuzione dei valori di numero di canali

# %%
plot_distribution(num_channels_list, 'Distribuzione dei Valori di Numero di Canali', 'Numero di Canali')

# %% [markdown]
# # Bit Depth

# %%
plot_distribution(bit_depths, 'Distribuzione dei Valori di Bit Depth', 'Bit Depth')

# %% [markdown]
# # Statistiche sulle classi

# %%
df_target = helper.estrai_classe_target(df)
df_target
# Out:
#                                               Nome file  Classe  \
# 1950                                         AHD_Airmar  Target
# 1951  SanctSound_CI04_04_acousticrelease_20200202T07...  Target
# 1952                                       20171104-1_1  Target
# 1953                                      20171104a-2_2  Target
# 1954                                      20171105a-3_3  Target
# ...                                                 ...     ...
# 2608           SanctSound_OC01_03_ship_20191106T223751Z  Target
# 2609           SanctSound_OC02_01_ship_20190419T233040Z  Target
# 2610           SanctSound_OC03_02_ship_20200228T080107Z  Target
# 2611         SanctSound_SB03_09_vessel_20200415T161235Z  Target
# 2612                                         ship_small  Target
#
#                       Sottoclasse  Ampiezza del segnale      Durata  \
# 1950  Acoustic Harassment Devices              0.762299    6.501587
# 1951             Acoustic release              1.000000   10.185667
# 1952                        Cargo              0.152562  457.000000
# 1953                        Cargo              0.077119  440.000000
# 1954                        Cargo              0.162010  297.000000
# ...                           ...                   ...         ...
# 2608                       Vessel              0.251221    5.305042
# 2609                       Vessel              0.326813   60.000000
# 2610                       Vessel              0.251221   60.000000
# 2611                       Vessel              0.251129    5.000021
# 2612                       Vessel              0.690488   51.876000
#
#       Frequenza  Numero di canali      Fase  Frequenza massima interna  \
# 1950      44100                 2  0.000000                        0.0
# 1951      48000                 1  0.000000                        0.0
# 1952      32000                 1  0.027270                        0.0
# 1953      32000                 1  0.027292                        0.0
# 1954      32000                 1  0.032642                        0.0
# ...         ...               ...       ...                        ...
# 2608      48000                 1  0.000000                        0.0
# 2609      48000                 1  0.000000                        0.0
# 2610      48000                 1 -0.000031                        0.0
# 2611      48000                 1  0.000000                        0.0
# 2612      32000                 2  0.000000                        0.0
#
#               Bit Depth Forma d'onda
# 1950  Signed 16 bit PCM    (286720,)
# 1951  Signed 16 bit PCM    (488912,)
# 1952       32 bit float  (14624000,)
# 1953       32 bit float  (14080000,)
# 1954       32 bit float   (9504000,)
# ...                 ...          ...
# 2608  Signed 16 bit PCM    (254642,)
# 2609  Signed 16 bit PCM   (2880000,)
# 2610  Signed 16 bit PCM   (2880000,)
# 2611  Signed 16 bit PCM    (240001,)
# 2612     MPEG Layer III   (1660032,)
#
# [663 rows x 11 columns]

# %%
df_notarget = helper.estrai_classe_noTarget(df)
df_notarget
# Out:
#                                               Nome file      Classe  \
# 0                  0f9867d8-fcf7-40d1-b846-3f7fb8100eb7  Non-Target
# 1                  2b68b3a9-7c0d-4452-bbe5-cc99b5d4fb61  Non-Target
# 2                  2f574049-3325-446c-a8ac-2e5b31e9e32f  Non-Target
# 3                  30679527-fd7a-4cad-8c7d-cb1bcc07604d  Non-Target
# 4                  f9652ad2-39f5-41b4-a8e4-89171a864f03  Non-Target
# ...                                                 ...         ...
# 1945  SanctSound_HI04_03_windwaves_20201220115634Z_3...  Non-Target
# 1946  SanctSound_MB02_04_wind_20200101T225838Z_36dBgain  Non-Target
# 1947  SanctSound_OC02_03_wind_20191205T223352Z_50dBgain  Non-Target
# 1948  SanctSound_PM05_01_windwaves_20191113T090002Z_...  Non-Target
# 1949      SanctSound_SB03_13_windwaves_20210105T213524Z  Non-Target
#
#         Sottoclasse  Ampiezza del segnale     Durata  Frequenza  \
# 0     Ambient Noise              0.226026  31.207619      44100
# 1     Ambient Noise              0.646487  31.207619      44100
# 2     Ambient Noise              0.391676  31.207619      44100
# 3     Ambient Noise              0.200377  31.207619      44100
# 4     Ambient Noise              0.753663  31.207619      44100
# ...             ...                   ...        ...        ...
# 1945  Wind and wave              0.654724  18.000354      48000
# 1946  Wind and wave              0.494232  18.000000      48000
# 1947  Wind and wave              0.386200   7.480000       4000
# 1948  Wind and wave              0.614258  15.011708      48000
# 1949  Wind and wave              0.199493   5.000021      48000
#
#       Numero di canali      Fase  Frequenza massima interna  \
# 0                    1 -0.068573                        0.0
# 1                    1  0.003324                        0.0
# 2                    1 -0.031078                        0.0
# 3                    1  0.013213                        0.0
# 4                    1  0.050887                        0.0
# ...                ...       ...                        ...
# 1945                 1  0.000000                        0.0
# 1946                 1 -0.000031                        0.0
# 1947                 1 -0.000031                        0.0
# 1948                 1  0.000000                        0.0
# 1949                 1  0.000000                        0.0
#
#               Bit Depth Forma d'onda
# 0        MPEG Layer III   (1376256,)
# 1        MPEG Layer III   (1376256,)
# 2        MPEG Layer III   (1376256,)
# 3        MPEG Layer III   (1376256,)
# 4        MPEG Layer III   (1376256,)
# ...                 ...          ...
# 1945  Signed 16 bit PCM    (864017,)
# 1946  Signed 16 bit PCM    (864000,)
# 1947  Signed 16 bit PCM     (29920,)
# 1948  Signed 16 bit PCM    (720562,)
# 1949  Signed 16 bit PCM    (240001,)
#
# [1950 rows x 11 columns]

# %% [markdown]
# Sample in Target

# %%
helper.sample_counter(df_target)
# Out:
# samples for Target Class:
# Sottoclasse
# Tanker                              240
# Passengership                       195
# Cargo                               111
# Tug                                  69
# Vessel                               24
# Sonar                                 7
# Echosounder                           4
# Scuba divers                          2
# Seal bomb                             2
# Seismic airguns surveys               2
# Underwater Communication Signals      2
# Acoustic Harassment Devices           1
# Acoustic release                      1
# Explosion                             1
# Fishing pinger                        1
# Seafloor fossil fuel processing       1
# Name: count, dtype: int64

# %% [markdown]
# Sample in Not-Target

# %%
helper.sample_counterNot(df_notarget)
# Out:
# samples for Non-Target Class:
# Sottoclasse
# Spinner Dolphin              114
# Fraser_s Dolphin              91
# Humpback Whale                90
# Striped Dolphin               85
# Long-Finned Pilot Whale       72
#                             ...
# Northern bottlenose whale      1
# Bryde_s Whale                  1
# Sea lion                       1
# Gray Seal                      1
# Red grouper                    1
# Name: count, Length: 96, dtype: int64

# %% [markdown]
# # Sample rates

# %%
plot_distribution(frequencies, 'Distribuzione dei Valori di Frequenza', 'Frequenza (Hz)')

# %% [markdown]
# Sample rates nella classe Target

# %%
helper.plot_frequency_distribution(df_target)
# Out:
# Sample Rate Massimo: 200000
# Sample Rate Minimo: 2000

# %% [markdown]
# sample rates nella classe Non-Target

# %%
helper.plot_frequency_distribution_not(df_notarget)
# Out:
# Sample Rate Massimo: 384000
# Sample Rate Minimo: 600

# %%
helper.plot_combined_frequency_distribution(df_target, df_notarget)

# %% [markdown]
# # Distribuzione durate audio

# %%
def plot_audio_durations_histogram(durations, bins=30):
    plt.figure(figsize=(12, 8))
    sns.histplot(durations, bins=bins, kde=True)
    plt.title('Distribuzione delle durate degli audio')
    plt.xlabel('Durata (secondi)')
    plt.ylabel('Frequenza')
    plt.grid(True)
    plt.show()

# %%
plot_audio_durations_histogram(durations)

# %% [markdown]
# distribuzione durate audio in Target

# %%
helper.plot_duration_target(df_target)
# Out:
# Max duration: 1887.0
# Min duration: 3.3668934240362813

# %% [markdown]
# distribuzione durate audio in Non-Target

# %%
helper.plot_duration_target(df_notarget)
# Out:
# Max duration: 1423.805941043084
# Min duration: 0.0536865234375

# %% [markdown]
# Distribuzione delle durate per entrambe le classi, con calcolo della mediana

# %%
helper.plot_combined_duration_distribution(df_target, df_notarget)
