# %%
import pandas as pd

# %%
df = pd.read_csv('C:/underwater-classification/oversampling/X_val.csv')

parent_counts = df['Parent'].value_counts()

# Filtra i Parent che hanno <= 9 occorrenze
parents_with_few_files = parent_counts[parent_counts < 7].index

# Filtra il DataFrame per mostrare solo questi Parent
filtered_df = df[df['Parent'].isin(parents_with_few_files)]

filtered_df[['File Name', 'Parent', 'Subclass']]
# Out:
#                                       File Name  \
# 342                         20160604-16_16_seg1
# 343                         20160604-16_16_seg2
# 344                         20160604-16_16_seg3
# 443                         20160625-19_19_seg1
# 444                         20160625-19_19_seg2
# 445                         20160625-19_19_seg3
# 446                         20160625-19_19_seg4
# 794                     20170412-96_114857_seg1
# 795                     20170412-96_114857_seg2
# 796                     20170412-96_114857_seg3
# 797                     20170412-96_114857_seg4
# 798                    20170503c-70_201813_seg1
# 799                    20170503c-70_201813_seg2
# 800                    20170503c-70_201813_seg3
# 889                    20170513a-79_201854_seg1
# 890                    20170513a-79_201854_seg2
# 891                    20170513a-79_201854_seg3
# 892                    20170513a-79_201854_seg4
# ...

# %%
#Non ci sono file da 1 o 9. Quindi andiamo ad escludere i file da 8 segmenti

# %%
#non ci sono file da 7 segmenti

# %% [markdown]
# file da 2 segmenti: 1
#
# file da 3 segmenti: 5
#
# file da 4 segmenti: 2
#
# file da 5 segmenti: 2
#
# file da 6 segmenti: 1

# %% [markdown]
# Possibili soluzioni:
#
# tre da 3
#
# uno da 6 con uno da 3
#
# uno da 4 e uno da 5
#
# uno da 2,uno da 3 e uno da 4
